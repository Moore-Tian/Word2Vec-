# %% [markdown]
# ### PJ1 动手训练一个词向量
#
# - 训练语料：[百度百科语料](https://elearning.fudan.edu.cn/courses/72208/files/4462367/download?download_frd=1)，约1.5G
#
# - `Python` 相关工具
#
#     - `Json` 解析
#
#     - [结巴分词](https://github.com/fxsjy/jieba)
#
#     - [词向量训练](https://radimrehurek.com/gensim/models/word2vec.html)
#
# - 基本要求（必做）
#
#     - 利用提供的语料训练得到一个 `Word2Vec` 词向量模型，并分析其效果
#
#     - 提交一份相关技术报告，需要包含
#
#         - 对所写的代码的解释
#
#         - 记录实验过程和心得体会
#
#         - 对课堂所学知识的理解
#
#         - 对实验结果的分析
#
# - 其他（选做）
#
#     - 鼓励查找相关资料，探讨如何降低训练代价，提升训练性能
#
#     - 鼓励分析 `Word2Vec` 中不同超参数对最后分词效果的影响（如窗口大小、迭代次数、向量维度等）
#
#     - 鼓励自主探索 `Word2Vec` 的两种不同实现方式（即 `CBOW` 和 `skip-gram`），并分析其优劣
#
#     - 鼓励进行数据分析，探讨如何更高效地利用数据
#
#     - 鼓励对结果进行可视化分析
#
#     - 鼓励基于本次实验进一步拓展，自主完成其他感兴趣的实验
#
#     - 以及分享其他在实验过程中发现的有趣现象

# %% [markdown]
# #### 下载数据（略）
#
# - 将数据从 `Elearning` 下载到本地

# %% [markdown]
# #### 安装相关的依赖包
#
# - `python` 安装教程请直接在线搜索
#
# - `json` 是 `python` 的内置库，无需额外安装
#
# - 本实验需要用到 `jieba` 和 `gensim`，需要提前安装

# %%
# %pip install jieba gensim
# Out:
# Requirement already satisfied: jieba in d:\anaconda3\lib\site-packages (0.42.1)
# Requirement already satisfied: gensim in d:\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in d:\anaconda3\lib\site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in d:\anaconda3\lib\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in d:\anaconda3\lib\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: pyfume in d:\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7)
# Requirement already satisfied: simpful in d:\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Requirement already satisfied: fst-pso in d:\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: typing-extensions in d:\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (4.7.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in d:\anaconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 数据处理
#
# - 使用 `json` 读取数据

# %%
import json

data = []

with open('baike_qa_train.json', 'r', encoding='utf-8') as f:
    for line in f.readlines():
        if line != '':
            sample = json.loads(line)
            data.append(sample.copy())

# %% [markdown]
# - 打印数据，查看格式

# %%
def display(data:list):
    print('len:', len(data))
    for i in range(5):
        print(data[i])

# %%
display(data)
# Out:
# len: 1425170
# {'qid': 'qid_5982723620932473219', 'category': '教育/科学-理工学科-地球科学', 'title': '人站在地球上为什么没有头朝下的感觉 ', 'desc': '', 'answer': '地球上重力作用一直是指向球心的，因此\r\n只要头远离球心，人们就回感到头朝上。'}
# {'qid': 'qid_5679706523376347837', 'category': '娱乐-宠物', 'title': '我的小baby', 'desc': '我的小baby-辛巴。温顺可爱的，两个月大的小家伙，第一次养狗，该注意什么呢？求指教～[爱你]', 'answer': '勤洗澡，养成好的卫生习惯'}
# {'qid': 'qid_6610724023825624555', 'category': '娱乐-度假旅游', 'title': '请问这起交通事故是谁的责任居多?小车和摩托车发生事故，在无红绿灯 ', 'desc': '小车和摩托车发生事故，在无红绿灯的十字路口，小停车看看左右，在觉得安全的情况下刹车慢慢以时速10公里左右的速度靠右行驶过路口，好没有出到十字路口正中时，被左边突然快速行驶过来的摩托车撞在车头前，摩托车主摔到膝盖和檫伤脸部，请问这起交通事故是谁的责任居多。如果双方都有责任的话，大概各占几成？~\r', 'answer': '通过没有信号控制的十字路口，应该减速慢性，让右边的车先行，按你说的，摩托车好像在汽车的左边，所以严格来说可能摩托车全责。当然还要看汽车是否证照齐全，是否饮酒等。具体由交警调查后认定。'}
# {'qid': 'qid_8948366474478096617', 'category': '电脑/网络-互联网', 'title': '松本面板可以配什么品牌的超五类模块?? ', 'desc': '', 'answer': 'AMP的试试吧，还有普天的。'}
# {'qid': 'qid_3057155567155332897', 'category': '生活-美食/烹饪', 'title': '请教怎么能很快能洗干净猪肠?有什么方法 ', 'desc': '有什么方法', 'answer': '先用清水冲一下,在用食盐反复的搓揉,直到肠的黏液全去掉为止,在用清水反复冲洗干净,最好把肠上的油去掉一些再下锅。'}

# %% [markdown]
# - 选取合适的部分作为最终的训练数据（可以探讨）

# %%
train_data = [i['answer'] for i in data[:1000]]

display(train_data)
# Out:
# len: 1000
# 地球上重力作用一直是指向球心的，因此
# 只要头远离球心，人们就回感到头朝上。
# 勤洗澡，养成好的卫生习惯
# 通过没有信号控制的十字路口，应该减速慢性，让右边的车先行，按你说的，摩托车好像在汽车的左边，所以严格来说可能摩托车全责。当然还要看汽车是否证照齐全，是否饮酒等。具体由交警调查后认定。
# AMP的试试吧，还有普天的。
# 先用清水冲一下,在用食盐反复的搓揉,直到肠的黏液全去掉为止,在用清水反复冲洗干净,最好把肠上的油去掉一些再下锅。

# %% [markdown]
# - 结巴分词（可以探讨不同的分词方式）

# %%
import jieba

seg_data = []
for i in train_data:
    seg_i = jieba.lcut(i)
    seg_data.append(seg_i)

display(seg_data)
# Out:
# len: 1000
# ['地球', '上', '重力', '作用', '一直', '是', '指向', '球心', '的', '，', '因此', '\r\n', '只要', '头', '远离', '球心', '，', '人们', '就', '回', '感到', '头朝', '上', '。']
# ['勤', '洗澡', '，', '养成', '好', '的', '卫生习惯']
# ['通过', '没有', '信号', '控制', '的', '十字路口', '，', '应该', '减速', '慢性', '，', '让', '右边', '的', '车', '先行', '，', '按', '你', '说', '的', '，', '摩托车', '好像', '在', '汽车', '的', '左边', '，', '所以', '严格来说', '可能', '摩托车', '全责', '。', '当然', '还要', '看', '汽车', '是否', '证照', '齐全', '，', '是否', '饮酒', '等', '。', '具体', '由', '交警', '调查', '后', '认定', '。']
# ['AMP', '的', '试试', '吧', '，', '还有', '普天', '的', '。']
# ['先', '用', '清水', '冲', '一下', ',', '在', '用', '食盐', '反复', '的', '搓揉', ',', '直到', '肠', '的', '黏液', '全', '去掉', '为止', ',', '在', '用', '清水', '反复', '冲洗', '干净', ',', '最好', '把', '肠', '上', '的', '油', '去掉', '一些', '再', '下锅', '。']

# %% [markdown]
# #### 训练
#
# - 直接使用相关包进行训练（可以探讨不同训练方式）

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences=seg_data, vector_size=100, window=5, min_count=1, workers=8)
model.save('word2vec.model')

# %% [markdown]
# #### 验证
#
# - 使用课堂讲授的相关知识验证所得模型的优劣，并进一步调整

# %%
model.wv.key_to_index # 获得所有词汇组
# Out:
# {'，': 0,
#  '的': 1,
#  ' ': 2,
#  '。': 3,
#  '\r': 4,
#  '、': 5,
#  ',': 6,
#  '\u3000': 7,
#  '是': 8,
#  '\r\n': 9,
#  '在': 10,
#  '了': 11,
#  '你': 12,
#  '：': 13,
#  '有': 14,
#  '.': 15,
#  '和': 16,
#  '可以': 17,
#  '就': 18,
#  '也': 19,
#  '我': 20,
#  '不': 21,
#  '）': 22,
#  '（': 23,
#  ')': 24,
#  '都': 25,
#  '(': 26,
#  '！': 27,
#  '会': 28,
#  '“': 29,
#  '”': 30,
#  '2': 31,
#  '1': 32,
#  '如果': 33,
#  '要': 34,
#  '一个': 35,
#  '上': 36,
#  '-': 37,
#  '3': 38,
#  '为': 39,
#  '对': 40,
#  '中': 41,
#  '好': 42,
#  '=': 43,
#  '人': 44,
#  '等': 45,
#  '到': 46,
#  '；': 47,
#  '很': 48,
#  '用': 49,
#  '或': 50,
#  '+': 51,
#  '他': 52,
#  '后': 53,
#  '没有': 54,
#  '自己': 55,
#  '？': 56,
#  '就是': 57,
#  '把': 58,
#  '与': 59,
#  '而': 60,
#  '~': 61,
#  '将': 62,
#  '多': 63,
#  '说': 64,
#  '这': 65,
#  '/': 66,
#  '去': 67,
#  '时': 68,
#  '可': 69,
#  '"': 70,
#  '能': 71,
#  '个': 72,
#  '所以': 73,
#  '5': 74,
#  '但': 75,
#  '还': 76,
#  '月': 77,
#  '4': 78,
#  '做': 79,
#  '可能': 80,
#  '治疗': 81,
#  '日': 82,
#  '问题': 83,
#  '这个': 84,
#  '给': 85,
#  '10': 86,
#  '年': 87,
#  '需要': 88,
#  '吃': 89,
#  '再': 90,
#  '什么': 91,
#  '系统': 92,
#  '以': 93,
#  '下': 94,
#  '我们': 95,
#  ':': 96,
#  '因为': 97,
#  '时候': 98,
#  '7': 99,
#  '不是': 100,
#  '然后': 101,
#  '孩子': 102,
#  '选择': 103,
#  '使': 104,
#  '点': 105,
#  '使用': 106,
#  '您': 107,
#  '不要': 108,
#  '方法': 109,
#  '从': 110,
#  '现在': 111,
#  '吧': 112,
#  '!': 113,
#  '应该': 114,
#  '并': 115,
#  '看': 116,
#  '皮肤': 117,
#  '让': 118,
#  '时间': 119,
#  '一般': 120,
#  '及': 121,
#  '大': 122,
#  '\ue5e5': 123,
#  '来': 124,
#  '还是': 125,
#  '啊': 126,
#  '被': 127,
#  '一些': 128,
#  '如': 129,
#  '更': 130,
#  '的话': 131,
#  '这样': 132,
#  '比较': 133,
#  '它': 134,
#  '情况': 135,
#  '她': 136,
#  '其': 137,
#  '里': 138,
#  '最': 139,
#  '一种': 140,
#  '中国': 141,
#  '不能': 142,
#  '那': 143,
#  '或者': 144,
#  '不会': 145,
#  '高': 146,
#  '一下': 147,
#  '?': 148,
#  '6': 149,
#  '．': 150,
#  '又': 151,
#  '地': 152,
#  '进行': 153,
#  '出现': 154,
#  '很多': 155,
#  '一定': 156,
#  '最好': 157,
#  '但是': 158,
#  '\n': 159,
#  '而且': 160,
#  'x': 161,
#  '》': 162,
#  '《': 163,
#  '主要': 164,
#  '还有': 165,
#  '不过': 166,
#  '于': 167,
#  '得': 168,
#  '克': 169,
#  '建议': 170,
#  '已经': 171,
#  '功能': 172,
#  '*': 173,
#  '注意': 174,
#  '影响': 175,
#  '呢': 176,
#  '一': 177,
#  '攻击': 178,
#  '则': 179,
#  '内': 180,
#  '小': 181,
#  '这种': 182,
#  '其他': 183,
#  '不同': 184,
#  '9': 185,
#  '进入': 186,
#  '想': 187,
#  '过': 188,
#  '服务器': 189,
#  '正常': 190,
#  '容易': 191,
#  '才': 192,
#  '同时': 193,
#  '由于': 194,
#  '>': 195,
#  '东西': 196,
#  '…': 197,
#  '开始': 198,
#  '温柔': 199,
#  '知道': 200,
#  '属性': 201,
#  '一样': 202,
#  '坦克': 203,
#  '·': 204,
#  '8': 205,
#  '15': 206,
#  '目前': 207,
#  '喜欢': 208,
#  '这些': 209,
#  '原因': 210,
#  '爱': 211,
#  '比': 212,
#  '先': 213,
#  '能力': 214,
#  '那么': 215,
#  ']': 216,
#  '他们': 217,
#  '请': 218,
#  '安装': 219,
#  '直接': 220,
#  '以上': 221,
#  '女人': 222,
#  'C': 223,
#  '医院': 224,
#  '作用': 225,
#  '工作': 226,
#  '[': 227,
#  '患者': 228,
#  '公司': 229,
#  '20': 230,
#  '没': 231,
#  '检查': 232,
#  '根据': 233,
#  '引起': 234,
#  '出来': 235,
#  '水': 236,
#  '买': 237,
#  '效果': 238,
#  '当': 239,
#  '当然': 240,
#  '采用': 241,
#  '电脑': 242,
#  '通过': 243,
#  '最后': 244,
#  '得到': 245,
#  '米': 246,
#  '元': 247,
#  '非常': 248,
#  '跳蚤': 249,
#  '—': 250,
#  '是否': 251,
#  '明显': 252,
#  '跟': 253,
#  '内容': 254,
#  '30': 255,
#  '技术': 256,
#  '只有': 257,
#  '其实': 258,
#  '次': 259,
#  '内存': 260,
#  '走': 261,
#  '～': 262,
#  '必须': 263,
#  '个人': 264,
#  '发生': 265,
#  '重要': 266,
#  '该': 267,
#  '由': 268,
#  '子宫': 269,
#  '^': 270,
#  '不错': 271,
#  '宝宝': 272,
#  '增加': 273,
#  '着': 274,
#  '所': 275,
#  '应': 276,
#  '之': 277,
#  '另外': 278,
#  '症状': 279,
#  '分钟': 280,
#  '这是': 281,
#  '一点': 282,
#  '提供': 283,
#  '设置': 284,
#  '写字楼': 285,
#  '减少': 286,
#  '觉得': 287,
#  '找': 288,
#  '任务': 289,
#  '技能': 290,
#  '简单': 291,
#  '能够': 292,
#  '太': 293,
#  '以后': 294,
#  '只要': 295,
#  '只': 296,
#  '对于': 297,
#  '方式': 298,
#  '网站': 299,
#  '水果': 300,
#  '造成': 301,
#  '怎么': 302,
#  '12': 303,
#  '出': 304,
#  'A': 305,
#  '市场': 306,
#  '产生': 307,
#  '较': 308,
#  '企业': 309,
#  '毛孔': 310,
#  '前': 311,
#  '产品': 312,
#  'NET': 313,
#  '了解': 314,
#  '干燥': 315,
#  '加': 316,
#  '希望': 317,
#  '表现': 318,
#  '你们': 319,
#  '游戏': 320,
#  '一起': 321,
#  '地方': 322,
#  '具有': 323,
#  '哦': 324,
#  '自然': 325,
#  '加入': 326,
#  '0': 327,
#  '打': 328,
#  '`': 329,
#  '即可': 330,
#  '两个': 331,
#  '导致': 332,
#  '冠脉': 333,
#  '任何': 334,
#  ';': 335,
#  '炒': 336,
#  '朋友': 337,
#  '叫': 338,
#  '之后': 339,
#  '成为': 340,
#  '发现': 341,
#  '认为': 342,
#  '魔剑': 343,
#  '吗': 344,
#  '里面': 345,
#  '扬州': 346,
#  '号': 347,
#  '要求': 348,
#  '女性': 349,
#  '因此': 350,
#  '只是': 351,
#  '所有': 352,
#  '因': 353,
#  '以及': 354,
#  '服务': 355,
#  '单位': 356,
#  '手术': 357,
#  '像': 358,
#  '者': 359,
#  '保持': 360,
#  '特别': 361,
#  '那个': 362,
#  '左右': 363,
#  '感觉': 364,
#  '已': 365,
#  '新': 366,
#  '看看': 367,
#  '不用': 368,
#  '按': 369,
#  '包括': 370,
#  '起来': 371,
#  '食物': 372,
#  '即': 373,
#  '经常': 374,
#  '无法': 375,
#  '首先': 376,
#  '环境': 377,
#  '超过': 378,
#  '形成': 379,
#  '美国': 380,
#  '一次': 381,
#  '疾病': 382,
#  '<': 383,
#  '武器': 384,
#  '装备': 385,
#  '肯定': 386,
#  '帮助': 387,
#  '投资': 388,
#  '比赛': 389,
#  '若': 390,
#  '孕妇': 391,
#  '发展': 392,
#  '达到': 393,
#  '越': 394,
#  '_': 395,
#  '父母': 396,
#  "'": 397,
#  '头发': 398,
#  '有效': 399,
#  '身体': 400,
#  '考虑': 401,
#  '只能': 402,
#  '推荐': 403,
#  'sin': 404,
#  '有些': 405,
#  '故障': 406,
#  '方面': 407,
#  '监控': 408,
#  '运动': 409,
#  '每个': 410,
#  '写': 411,
#  '应用': 412,
#  '过程': 413,
#  '战场': 414,
#  '别人': 415,
#  '英语': 416,
#  '软件': 417,
#  'a': 418,
#  '安全': 419,
#  '00': 420,
#  '纵隔': 421,
#  '分': 422,
#  '--': 423,
#  '净化': 424,
#  '设计': 425,
#  '基本': 426,
#  '每天': 427,
#  '放': 428,
#  '肌肤': 429,
#  '放入': 430,
#  '男人': 431,
#  '技': 432,
#  '吃饭': 433,
#  '升级': 434,
#  '大量': 435,
#  '一天': 436,
#  '价格': 437,
#  '标准': 438,
#  '网络': 439,
#  '表示': 440,
#  '为了': 441,
#  '作为': 442,
#  '含有': 443,
#  '按照': 444,
#  '北京': 445,
#  'B': 446,
#  '规定': 447,
#  '存在': 448,
#  '盐': 449,
#  '管理': 450,
#  '下载': 451,
#  '人们': 452,
#  '11': 453,
#  '２': 454,
#  '大家': 455,
#  '说明': 456,
#  '长': 457,
#  '用于': 458,
#  '多少': 459,
#  '上海': 460,
#  '式': 461,
#  '小时': 462,
#  '玩家': 463,
#  '质量': 464,
#  '一直': 465,
#  '例如': 466,
#  '以下': 467,
#  '职业': 468,
#  '－': 469,
#  '天': 470,
#  '比如': 471,
#  '状态': 472,
#  '脂肪': 473,
#  '用户': 474,
#  '人民币': 475,
#  '完全': 476,
#  '学生': 477,
#  '其它': 478,
#  '学习': 479,
#  '之间': 480,
#  '升值': 481,
#  '健康': 482,
#  '成': 483,
#  '回答': 484,
#  '控制': 485,
#  '便': 486,
#  '尤其': 487,
#  '不好': 488,
#  '０': 489,
#  '风': 490,
#  '真的': 491,
#  '发育': 492,
#  '许多': 493,
#  '信息': 494,
#  '属于': 495,
#  '处理': 496,
#  '现象': 497,
#  '钱': 498,
#  '等等': 499,
#  '各': 500,
#  '支持': 501,
#  '实现': 502,
#  '生活': 503,
#  '找到': 504,
#  '水分': 505,
#  '删除': 506,
#  '研究': 507,
#  '组': 508,
#  '决定': 509,
#  '外': 510,
#  '生肖': 511,
#  '严重': 512,
#  '每': 513,
#  '结果': 514,
#  '１': 515,
#  '世界': 516,
#  '甚至': 517,
#  '维生素': 518,
#  '有人': 519,
#  '【': 520,
#  '二': 521,
#  '】': 522,
#  '且': 523,
#  '因素': 524,
#  '不管': 525,
#  '均': 526,
#  '代码': 527,
#  '国际': 528,
#  '项目': 529,
#  '上面': 530,
#  '虽然': 531,
#  '谁': 532,
#  '医生': 533,
#  '自动': 534,
#  '利用': 535,
#  '拥有': 536,
#  '是因为': 537,
#  '模式': 538,
#  '继续': 539,
#  '怀孕': 540,
#  '点击': 541,
#  '2000': 542,
#  '空竹': 543,
#  '少': 544,
#  '成功': 545,
#  '饮食': 546,
#  '之一': 547,
#  '适合': 548,
#  '呀': 549,
#  '每日': 550,
#  '范围': 551,
#  'VS': 552,
#  '无': 553,
#  '胎儿': 554,
#  '３': 555,
#  '血管': 556,
#  '强': 557,
#  '要是': 558,
#  '天堂': 559,
#  '资金': 560,
#  '就行了': 561,
#  '专业': 562,
#  '土豆': 563,
#  '指': 564,
#  '向': 565,
#  'f': 566,
#  '最大': 567,
#  '除了': 568,
#  '来说': 569,
#  '食品': 570,
#  '生产': 571,
#  '搭桥': 572,
#  '相信': 573,
#  '修改': 574,
#  '完成': 575,
#  '如下': 576,
#  '减肥': 577,
#  '你好': 578,
#  '低': 579,
#  '听': 580,
#  '问': 581,
#  '改变': 582,
#  '学校': 583,
#  '操作': 584,
#  '站': 585,
#  '是不是': 586,
#  '部分': 587,
#  '才能': 588,
#  '条件': 589,
#  '量': 590,
#  '飞机': 591,
#  '99': 592,
#  '掉': 593,
#  '处': 594,
#  '两种': 595,
#  '59': 596,
#  '颜色': 597,
#  '第一': 598,
#  '靠': 599,
#  '值': 600,
#  '提高': 601,
#  '相同': 602,
#  '习惯': 603,
#  '全部': 604,
#  '大学': 605,
#  '位置': 606,
#  '费用': 607,
#  '三': 608,
#  '睡眠': 609,
#  '材料': 610,
#  '国家': 611,
#  '其中': 612,
#  '50': 613,
#  '100': 614,
#  '运行': 615,
#  '仪式': 616,
#  '喝': 617,
#  '及时': 618,
#  '猫咪': 619,
#  '并且': 620,
#  '快': 621,
#  '显示': 622,
#  '活动': 623,
#  '内政': 624,
#  '13': 625,
#  '行为': 626,
#  '阿达茨': 627,
#  '呵呵': 628,
#  '球队': 629,
#  '这里': 630,
#  '解决': 631,
#  '入宅': 632,
#  '以前': 633,
#  'vs': 634,
#  '房地产': 635,
#  '看到': 636,
#  '打开': 637,
#  '客户': 638,
#  '此': 639,
#  '病变': 640,
#  '改善': 641,
#  '文件': 642,
#  '很大': 643,
#  '妇女': 644,
#  '随着': 645,
#  '啦': 646,
#  '需求': 647,
#  '碎': 648,
#  'II': 649,
#  '开': 650,
#  '基金': 651,
#  '类': 652,
#  '有关': 653,
#  '阴道': 654,
#  '告诉': 655,
#  '需': 656,
#  '就要': 657,
#  '|': 658,
#  '火': 659,
#  '面膜': 660,
#  '距离': 661,
#  '这么': 662,
#  '清楚': 663,
#  '完': 664,
#  '却': 665,
#  '至': 666,
#  '专家': 667,
#  '长期': 668,
#  '全面': 669,
#  '中心': 670,
#  '平台': 671,
#  '型': 672,
#  '猫': 673,
#  '从而': 674,
#  '变得': 675,
#  '重新': 676,
#  '第': 677,
#  '％': 678,
#  '好评': 679,
#  '水平': 680,
#  '国内': 681,
#  '接受': 682,
#  '生长': 683,
#  '煮': 684,
#  '约': 685,
#  '之前': 686,
#  '办法': 687,
#  '拿': 688,
#  '经验': 689,
#  '意思': 690,
#  '含': 691,
#  '为什么': 692,
#  '事': 693,
#  '知识': 694,
#  '80': 695,
#  '相对': 696,
#  'Windows': 697,
#  '我国': 698,
#  '阳历': 699,
#  '车': 700,
#  '...': 701,
#  '成虫': 702,
#  'y': 703,
#  '死亡': 704,
#  '担心': 705,
#  '事情': 706,
#  '加上': 707,
#  'Ａ': 708,
#  '吸收': 709,
#  '另': 710,
#  'D': 711,
#  '数据': 712,
#  '蔬菜': 713,
#  '伤害': 714,
#  '变成': 715,
#  '几个': 716,
#  '妈妈': 717,
#  '路': 718,
#  '天线': 719,
#  '级': 720,
#  '类型': 721,
#  '关系': 722,
#  '分别': 723,
#  '们': 724,
#  '度': 725,
#  '药物': 726,
#  '食用': 727,
#  '人体': 728,
#  '洋葱': 729,
#  '多种': 730,
#  '您好': 731,
#  '否则': 732,
#  '干净': 733,
#  '卖': 734,
#  '主战': 735,
#  '调整': 736,
#  '小儿': 737,
#  '带': 738,
#  '坚持': 739,
#  '盖茨': 740,
#  '关键': 741,
#  '每次': 742,
#  '大小': 743,
#  '更加': 744,
#  '压力': 745,
#  '程度': 746,
#  '部位': 747,
#  '倒': 748,
#  '获得': 749,
#  '补充': 750,
#  '积分': 751,
#  '平时': 752,
#  '干': 753,
#  '24': 754,
#  '相关': 755,
#  '可是': 756,
#  '良': 757,
#  '60': 758,
#  '方向': 759,
#  '良好': 760,
#  '能量': 761,
#  '热水器': 762,
#  '实际': 763,
#  '基础': 764,
#  '变化': 765,
#  '洗': 766,
#  '性能': 767,
#  '各种': 768,
#  '避开': 769,
#  '家里': 770,
#  '结合': 771,
#  '排名': 772,
#  '不仅': 773,
#  '保证': 774,
#  '狗': 775,
#  '证明': 776,
#  '差': 777,
#  '工艺': 778,
#  '岁': 779,
#  '三个': 780,
#  '本身': 781,
#  '购买': 782,
#  '×': 783,
#  '普通': 784,
#  '如何': 785,
#  '汁': 786,
#  '称号': 787,
#  '200': 788,
#  '确定': 789,
#  '提示': 790,
#  '防止': 791,
#  '密码': 792,
#  '同样': 793,
#  'θ': 794,
#  '暂时': 795,
#  '老': 796,
#  '数': 797,
#  '交流': 798,
#  '受到': 799,
#  '目标': 800,
#  '大部分': 801,
#  '丰富': 802,
#  '下面': 803,
#  '那样': 804,
#  '还要': 805,
#  '反复': 806,
#  '适用': 807,
#  '祝': 808,
#  '地址': 809,
#  '苹果': 810,
#  'X': 811,
#  '具体': 812,
#  '通常': 813,
#  '避免': 814,
#  '土': 815,
#  '疗法': 816,
#  '阴历': 817,
#  '分泌': 818,
#  '杀': 819,
#  '18': 820,
#  '不断': 821,
#  '河豚鱼': 822,
#  '开发': 823,
#  '性': 824,
#  '四': 825,
#  '牛奶': 826,
#  '恢复': 827,
#  '攻击力': 828,
#  '双方': 829,
#  '风险': 830,
#  '主板': 831,
#  '有没有': 832,
#  '至于': 833,
#  '那些': 834,
#  '机会': 835,
#  '麻烦': 836,
#  '精神': 837,
#  '加工': 838,
#  '商务': 839,
#  '美丽': 840,
#  '地区': 841,
#  '最近': 842,
#  '也许': 843,
#  '不到': 844,
#  '一切': 845,
#  '职工': 846,
#  '目的': 847,
#  '起': 848,
#  '综合': 849,
#  '建筑': 850,
#  '处于': 851,
#  '河豚': 852,
#  'n': 853,
#  '1000': 854,
#  '时期': 855,
#  '战斗': 856,
#  '500': 857,
#  '消失': 858,
#  '男性': 859,
#  '感染': 860,
#  '语言': 861,
#  '放在': 862,
#  '差不多': 863,
#  '线': 864,
#  '╬': 865,
#  '属': 866,
#  '经济': 867,
#  '日本': 868,
#  '本': 869,
#  '启动': 870,
#  '登记': 871,
#  '分析': 872,
#  '适量': 873,
#  '速度': 874,
#  '枭龙': 875,
#  '适当': 876,
#  '进去': 877,
#  '总': 878,
#  '毫米': 879,
#  '＋': 880,
#  '介绍': 881,
#  '雷': 882,
#  '40': 883,
#  '品牌': 884,
#  '同': 885,
#  '本人': 886,
#  '即使': 887,
#  '成分': 888,
#  '眼睛': 889,
#  '物质': 890,
#  '固定': 891,
#  '花': 892,
#  '学': 893,
#  '自身': 894,
#  '换': 895,
#  '原来': 896,
#  '方便': 897,
#  '钙': 898,
#  '添加': 899,
#  '商业': 900,
#  '那里': 901,
#  '导弹系统': 902,
#  '行': 903,
#  '小心': 904,
#  '常见': 905,
#  '中毒': 906,
#  '一个月': 907,
#  '结婚': 908,
#  '程序': 909,
#  '亲朋好友': 910,
#  '登陆': 911,
#  '执行': 912,
#  '而是': 913,
#  '22': 914,
#  '今天': 915,
#  '所谓': 916,
#  '一条': 917,
#  '25': 918,
#  '测试': 919,
#  '练习': 920,
#  '..': 921,
#  '胡萝卜': 922,
#  '微软': 923,
#  '经过': 924,
#  '谢谢': 925,
#  '第二': 926,
#  '180': 927,
#  '养成': 928,
#  '休息': 929,
#  '减轻': 930,
#  '音乐': 931,
#  '某些': 932,
#  '话': 933,
#  '进球数': 934,
#  '带来': 935,
#  '14': 936,
#  '心': 937,
#  '列表': 938,
#  '魅力': 939,
#  '城市': 940,
#  '第一次': 941,
#  '小组': 942,
#  '搭桥术': 943,
#  '资料': 944,
#  '晚上': 945,
#  '不必': 946,
#  'QQ': 947,
#  '粉': 948,
#  '穿': 949,
#  '自由': 950,
#  '制成': 951,
#  '患儿': 952,
#  '异常': 953,
#  '原': 954,
#  '龙': 955,
#  '香': 956,
#  '下降': 957,
#  '弓': 958,
#  '工资': 959,
#  '全球': 960,
#  '转': 961,
#  '冲洗': 962,
#  '难': 963,
#  '设': 964,
#  '真正': 965,
#  '格式': 966,
#  '银行': 967,
#  '经': 968,
#  '西': 969,
#  '药': 970,
#  '答案': 971,
#  '爱问': 972,
#  '代表': 973,
#  'Ping': 974,
#  '提问': 975,
#  '网上': 976,
#  '流产': 977,
#  '学会': 978,
#  '癫痫': 979,
#  '尽量': 980,
#  '激光': 981,
#  '21': 982,
#  '反应': 983,
#  '平均': 984,
#  '对方': 985,
#  '时请': 986,
#  '选': 987,
#  'd': 988,
#  '咨询': 989,
#  '特点': 990,
#  '类似': 991,
#  '历史': 992,
#  '上网': 993,
#  '农历': 994,
#  '玩': 995,
#  '稳定': 996,
#  '正确': 997,
#  '快乐': 998,
#  '＝': 999,
#  ...}

# %%
model.wv.vectors.shape # 查看词向量大小
# Out:
# (21558, 100)

# %%
model.wv['的'] # 得到词的词向量
# Out:
# array([-1.5698346 ,  1.1034702 ,  0.1396582 ,  1.4998164 , -1.1118265 ,
#        -2.8297575 ,  0.5615042 ,  2.2404068 , -1.4903784 , -1.802028  ,
#        -0.18213691, -2.4421303 ,  0.07965308,  0.7723    ,  1.169817  ,
#        -1.20225   ,  0.85013604, -1.3623807 ,  0.0092062 , -2.530962  ,
#         1.776783  ,  0.74232477,  1.350839  , -1.398957  , -0.3458412 ,
#         0.24692692, -1.5574671 , -0.09226742, -0.48521617, -0.7519789 ,
#         1.7162942 , -0.5305073 ,  0.40934592, -1.6406194 ,  0.11653597,
#         1.605797  ,  1.5937049 , -0.7445113 , -1.423545  , -2.6873953 ,
#        -0.12889306, -0.72389275, -0.8923072 ,  0.09756673,  0.57310253,
#        -0.364879  , -1.4789329 ,  0.22828555,  0.2769081 ,  1.8968172 ,
#         1.02741   , -1.7636787 , -1.903095  , -0.4465012 ,  0.09644181,
#         0.6801612 ,  0.8308344 ,  0.34183726, -1.0312793 ,  0.85901403,
#        -0.7056815 ,  0.72761226,  0.6363439 , -0.3039125 , -1.0506647 ,
#         1.5530902 , -0.02418057,  0.69320595, -1.3190293 ,  1.3466258 ,
#        -0.20698667,  1.0025947 ,  1.7597032 , -0.52790314,  1.2669733 ,
#         0.10290254,  0.05072436, -1.016999  , -0.91478246, -0.20941389,
#        -1.3722166 , -0.33616486,  0.13386138,  2.4038692 , -0.85767657,
#        -0.09963185,  1.8002304 ,  1.172614  ,  0.82387334,  0.7992767 ,
#         1.3008095 ,  0.6167337 ,  0.0265488 ,  1.2568345 ,  2.4046557 ,
#         1.3427474 , -0.1313211 ,  0.11197663,  0.1547905 ,  0.12906665],
#       dtype=float32)

# %%
model.wv.similarity('中国', '美国') # 计算两个词的余弦相似度
# Out:
# 0.9992347

# %%
model.wv.most_similar('中国') # 取出与“中国”最相似的10个词
# Out:
# [('系统', 0.9997972846031189),
#  ('将', 0.999756395816803),
#  ('以', 0.9997316002845764),
#  ('即可', 0.9996917247772217),
#  ('技术', 0.9996709227561951),
#  ('按', 0.9995360374450684),
#  ('武器', 0.9995312690734863),
#  ('和', 0.9995248913764954),
#  ('与', 0.9994613528251648),
#  ('设置', 0.9994303584098816)]

# %%
model.wv.most_similar(positive=["上海", "中国"], negative=["纽约"]) # 获得 上海-中国+纽约 的词
# Out:
# [('n', 0.9694655537605286),
#  ('II', 0.9685978293418884),
#  ('避开', 0.9678846597671509),
#  ('分析', 0.9675965309143066),
#  ('VS', 0.9675793051719666),
#  ('vs', 0.9675726294517517),
#  ('·', 0.9673287868499756),
#  ('天堂', 0.9664450883865356),
#  ('风', 0.9660134315490723),
#  ('登陆', 0.9658693671226501)]

# %%
model.wv.closer_than("上海", "中国") # 比 中国 更接近 上海 的词汇
# Out:
# ['.',
#  '（',
#  '为',
#  '等',
#  '；',
#  '或',
#  '"',
#  '个',
#  '年',
#  ':',
#  '点',
#  '?',
#  '．',
#  '进行',
#  '\n',
#  '》',
#  '《',
#  '克',
#  '功能',
#  '一',
#  '攻击',
#  '服务器',
#  '…',
#  '属性',
#  '·',
#  '15',
#  '以上',
#  'C',
#  '20',
#  '水',
#  '米',
#  '元',
#  '—',
#  '内容',
#  '30',
#  '技术',
#  '次',
#  '另外',
#  '分钟',
#  '写字楼',
#  '技能',
#  'A',
#  'NET',
#  '干燥',
#  '即可',
#  ';',
#  '炒',
#  '魔剑',
#  '扬州',
#  '超过',
#  '美国',
#  '武器',
#  '比赛',
#  '监控',
#  '英语',
#  '--',
#  '净化',
#  '基本',
#  '网络',
#  '表示',
#  '为了',
#  '北京',
#  '２',
#  '式',
#  '小时',
#  '以下',
#  '－',
#  '天',
#  '之间',
#  '０',
#  '风',
#  '等等',
#  '各',
#  '删除',
#  '组',
#  '决定',
#  '生肖',
#  '１',
#  '【',
#  '不管',
#  '均',
#  '模式',
#  '空竹',
#  '之一',
#  '每日',
#  'VS',
#  '３',
#  '天堂',
#  '就行了',
#  '食品',
#  '站',
#  '量',
#  '99',
#  '第一',
#  '值',
#  '50',
#  '100',
#  '球队',
#  '妇女',
#  'II',
#  '有关',
#  '|',
#  '％',
#  '好评',
#  '煮',
#  '80',
#  '...',
#  '成虫',
#  'D',
#  '路',
#  '级',
#  '类型',
#  '分别',
#  '度',
#  '洋葱',
#  '多种',
#  '主战',
#  '积分',
#  '干',
#  '24',
#  '相关',
#  '60',
#  '方向',
#  '避开',
#  '排名',
#  '狗',
#  '岁',
#  '×',
#  '汁',
#  '称号',
#  '200',
#  '暂时',
#  '苹果',
#  '避免',
#  '疗法',
#  '牛奶',
#  '商务',
#  '起',
#  'n',
#  '线',
#  '日本',
#  '本',
#  '分析',
#  '毫米',
#  '＋',
#  '40',
#  '眼睛',
#  '商业',
#  '亲朋好友',
#  '登陆',
#  '今天',
#  '25',
#  '测试',
#  '胡萝卜',
#  '第二',
#  '进球数',
#  '列表',
#  '魅力',
#  '小组',
#  '搭桥术',
#  '龙',
#  '香',
#  '全球',
#  '转',
#  '设',
#  '西',
#  '提问',
#  '平均',
#  '时请',
#  '特点',
#  '＝',
#  '签证',
#  '16',
#  '地图',
#  '剑',
#  '提交',
#  '蒜',
#  '煎',
#  '美',
#  '折旧',
#  '90',
#  '技巧',
#  '诊断',
#  '做法',
#  '―',
#  '护卫',
#  'e',
#  '有毒',
#  '合理',
#  '称',
#  '原则',
#  'Web',
#  '命令',
#  '参考',
#  '关于',
#  '顺利',
#  '粗大',
#  '组成',
#  '装甲',
#  '法',
#  '23',
#  'Eleven',
#  '计算机',
#  '名称',
#  '连续',
#  '物',
#  '除',
#  '此外',
#  '顺序',
#  '全',
#  '５',
#  '橄榄油',
#  '\\',
#  '鲜',
#  '种类',
#  '抽签',
#  '发动',
#  '最高',
#  '维护',
#  '导弹',
#  '员工',
#  '敏捷性',
#  '上述',
#  '破坏',
#  '黑',
#  '功效',
#  '铜',
#  '种',
#  '45',
#  '铜层',
#  '势力',
#  '万',
#  '姓',
#  '梨',
#  'T',
#  '练级',
#  '取',
#  '古代',
#  '‘',
#  '地点',
#  '秒',
#  '为止',
#  '用来',
#  '新浪',
#  '发表',
#  '限制',
#  '保湿',
#  '糖',
#  '℃',
#  '过滤',
#  '味精',
#  '努力',
#  '柠檬',
#  '强奸',
#  '蜂蜜',
#  '分为',
#  '体',
#  '账号',
#  '进程',
#  '和平',
#  '霜',
#  '难以',
#  '间',
#  '-----',
#  '800',
#  '损坏',
#  '白',
#  '排除',
#  '菜',
#  '定义',
#  'F',
#  '美军',
#  '南',
#  'I',
#  '四川',
#  '文章',
#  '小米',
#  '原料',
#  'O',
#  '酱',
#  '一边',
#  '愈',
#  '心绞痛',
#  '基于',
#  'Rnd',
#  '铜包钢',
#  '五',
#  '超级',
#  '印度',
#  '东',
#  'R',
#  '英国',
#  '冲田',
#  '版',
#  '面积',
#  '氏',
#  '民族',
#  '欧洲杯',
#  '2A6',
#  '小于',
#  '花椒',
#  '军事',
#  '预选赛',
#  '客场',
#  '第二名',
#  '到达',
#  '根',
#  '为氏',
#  '腌',
#  '命中',
#  '芝麻',
#  '位于',
#  '去皮',
#  '公里',
#  '防治',
#  '卢森堡',
#  '质',
#  '下列',
#  '车体',
#  '此类',
#  '剩下',
#  '机',
#  '剂',
#  '插入',
#  '出发',
#  '好象',
#  '出口',
#  '电子',
#  '临时',
#  '之中',
#  '白菜',
#  '旅游',
#  '第五',
#  '炸',
#  '1200',
#  '生',
#  '专用',
#  '今年',
#  '外语',
#  '防辐射',
#  '三种',
#  '周',
#  '债券',
#  '月份',
#  '感',
#  '德国',
#  '700',
#  '体力',
#  '累计',
#  '5000',
#  '01',
#  '环节',
#  '卷',
#  '连铸',
#  '调口',
#  '口服',
#  '号线',
#  '消灭',
#  '配方',
#  '少许',
#  'is',
#  '白色',
#  '公式',
#  'IP',
#  '通畅',
#  '图',
#  '力',
#  '两',
#  '元至',
#  '冠心病',
#  'g',
#  '对阵',
#  '子弹',
#  '项',
#  '之符',
#  '不当',
#  '3000',
#  'and',
#  '税',
#  '入',
#  '金',
#  '雪山',
#  '新鲜',
#  '格儿',
#  '突出',
#  '饭店',
#  '宫腔镜',
#  '33',
#  '电源',
#  '史密斯',
#  '另一方面',
#  '浙江',
#  '姜',
#  '刻录',
#  '防水',
#  '一组',
#  '病毒',
#  '面粉',
#  '用药',
#  '歼',
#  '角色',
#  '32',
#  '29',
#  '申请表',
#  '国',
#  '地铁',
#  '海',
#  '蛋白',
#  '通知',
#  '湖',
#  '颗',
#  '课堂',
#  '德军',
#  '≤',
#  'AC',
#  '石',
#  '陈',
#  '毫克',
#  '行政',
#  '双黄',
#  '香港',
#  '仲裁',
#  '3%',
#  '空调',
#  '总在',
#  '额',
#  '文',
#  '十年',
#  '第三国',
#  '总之',
#  '极',
#  '2002',
#  '打成',
#  '焦',
#  '黄连',
#  '动画',
#  '南北',
#  '打造',
#  '通信',
#  '蓝蓝的',
#  '划分',
#  '日期',
#  '方',
#  '我要',
#  '早上',
#  '胜负',
#  '日程',
#  'D2',
#  '忌食',
#  '电',
#  '黄柏',
#  '&',
#  '分成',
#  '饮料',
#  '洗浴',
#  '寺',
#  '症',
#  '离',
#  '703',
#  '古',
#  '佛塔',
#  '锤',
#  '澜沧江',
#  '目不窥园']

# %% [markdown]
# #### 调整和其他（略）
